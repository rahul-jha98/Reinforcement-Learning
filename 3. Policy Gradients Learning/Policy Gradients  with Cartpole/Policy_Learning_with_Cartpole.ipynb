# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul-jha98/Reinforcement-Learning/blob/master/3.%20Policy%20Gradients%20Learning/Policy%20Gradients%20%20with%20Cartpole/Policy_Learning_with_Cartpole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Step 0: Preparing Colab for rendering the environment and installing GYM 🏗️

# %%
# !pip install pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %%
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %% [markdown]
# ## Step 1: Importing the libraries 📚

# %%
## Importing GYM to make our environment
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only

import tensorflow.compat.v1 as tf      # Tensorflow compat for v1 functionalities
import tensorflow as tf2               # Importing tf2 for some intitalizers
import numpy as np                     # Handle matrices


import random                       # Handling random number generation

from skimage import transform       # Help us to preprocess the frames
from skimage.color import rgb2gray  # Help us to gray our frames

import matplotlib.pyplot as plt      # Display graphs

from collections import deque       # Ordered collection with ends

import warnings # This ignore all the warning messages that are normally printed during the training because of skiimage
warnings.filterwarnings('ignore')

# %%
## Disable eager execution to make it compatible with tf session module
tf.disable_eager_execution()

# %% [markdown]
# ## Creating the environment 🎮

# %%
env = gym.make('CartPole-v0') 
env = env.unwrapped

## Due to high variance in Policy Gradient, we set a seed for reporducability
env.seed(1)
# Out:
# [1]

# %% [markdown]
# ## Step 3: Set up our hyperparameters ⚗️

# %%
## ENVIRONMENT Hyperparameters
state_size = env.observation_space.sample().shape[0]
action_size = env.action_space.n

## TRAINING Hyperparameters
max_episodes = 1000
learning_rate = 0.005
gamma = 0.95 # Discount rate

# %% [markdown]
# ## Step 4 : Define the preprocessing functions ⚙️
# This function takes <b>the rewards and perform discounting.</b>

# %%
def discount_and_normalize_rewards(episode_rewards):
    discounted_episode_rewards = np.zeros_like(episode_rewards)
    cumulative = 0.0
    for i in reversed(range(len(episode_rewards))):
        cumulative = cumulative * gamma + episode_rewards[i]
        discounted_episode_rewards[i] = cumulative
    
    mean = np.mean(discounted_episode_rewards)
    std = np.std(discounted_episode_rewards)
    discounted_episode_rewards = (discounted_episode_rewards - mean) / (std)
    
    return discounted_episode_rewards

# %% [markdown]
# ## Step 5: Create our Policy Gradient Neural Network model 🧠

# %% [markdown]
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/Policy%20Gradients/Cartpole/assets/catpole.png">
#
# The idea is simple:
# - Our state which is an array of 4 values will be used as an input.
# - Our NN is 3 fully connected layers.
# - Our output activation function is softmax that squashes the outputs to a probability distribution (for instance if we have 4, 2, 6 --> softmax --> (0.4, 0.2, 0.6)

# %%
with tf.name_scope("inputs"):
    input_ = tf.placeholder(tf.float32, [None, state_size], name="input_")
    actions = tf.placeholder(tf.int32, [None, action_size], name="actions")
    discounted_episode_rewards_ = tf.placeholder(tf.float32, [None,], name="discounted_episode_rewards")
    
    # Add this placeholder for having this variable in tensorboard
    mean_reward_ = tf.placeholder(tf.float32 , name="mean_reward")

    with tf.name_scope("fc1"):
        fc1 = tf.layers.Dense(units = 10,
                              activation=tf.nn.relu,
                              kernel_initializer=tf2.keras.initializers.GlorotUniform(),
                              bias_initializer=tf2.keras.initializers.GlorotUniform())(input_)

    with tf.name_scope("fc2"):
        fc2 = tf.layers.Dense(units = action_size,
                              activation= tf.nn.relu,
                              kernel_initializer=tf2.keras.initializers.GlorotUniform(),
                              bias_initializer=tf2.keras.initializers.GlorotUniform())(fc1)

    with tf.name_scope("fc3"):
        fc3 = tf.layers.Dense(units = action_size,
                              activation= None,
                              kernel_initializer=tf2.keras.initializers.GlorotUniform(),
                              bias_initializer=tf2.keras.initializers.GlorotUniform())(fc2)

    with tf.name_scope("softmax"):
        action_distribution = tf.nn.softmax(fc3)

    with tf.name_scope("loss"):
        # tf.nn.softmax_cross_entropy_with_logits computes the cross entropy of the result after applying the softmax function
        # If you have single-class labels, where an object can only belong to one class, you might now consider using 
        # tf.nn.sparse_softmax_cross_entropy_with_logits so that you don't have to convert your labels to a dense one-hot array. 
        neg_log_prob = tf.nn.softmax_cross_entropy_with_logits_v2(logits = fc3, labels = actions)
        loss = tf.reduce_mean(neg_log_prob * discounted_episode_rewards_) 
        
    
    with tf.name_scope("train"):
        train_opt = tf.train.AdamOptimizer(learning_rate).minimize(loss)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# ## Step 6: Set up Tensorboard 📊

# %%
# Setup TensorBoard Writer
writer = tf.summary.FileWriter("/tensorboard/pg/1")

## Losses
tf.summary.scalar("Loss", loss)

## Reward mean
tf.summary.scalar("Reward_mean", mean_reward_)

write_op = tf.summary.merge_all()

# %% [markdown]
# ## Step 7: Train our Agent 🏃‍♂️

# %% [markdown]
#     Algo:
#
#       Create the NN
#       maxReward = 0 # Keep track of maximum reward
#       For episode in range(max_episodes):
#           episode + 1
#           reset environment
#           reset stores (states, actions, rewards)
#
#           For each step:
#               Choose action a
#               Perform action a
#               Store s, a, r
#               If done:
#                   Calculate sum reward
#                   Calculate gamma Gt
#                   Optimize

# %%
allRewards = []
total_rewards = 0
maximumRewardRecorded = 0
episode = 0
episode_states, episode_actions, episode_rewards = [],[],[]

saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for episode in range(max_episodes):
        
        episode_rewards_sum = 0

        # Launch the game
        state = env.reset()
        
        env.render()
           
        while True:
            
            # Choose action a, remember WE'RE NOT IN A DETERMINISTIC ENVIRONMENT, WE'RE OUTPUT PROBABILITIES.
            action_probability_distribution = sess.run(action_distribution, feed_dict={input_: state.reshape([1,4])})
            
            action = np.random.choice(range(action_probability_distribution.shape[1]), p=action_probability_distribution.ravel())  # select action w.r.t the actions prob

            # Perform a
            new_state, reward, done, info = env.step(action)

            # Store s, a, r
            episode_states.append(state)
                        
            # For actions because we output only one (the index) we need 2 (1 is for the action taken)
            # We need [0., 1.] (if we take right) not just the index
            action_ = np.zeros(action_size)
            action_[action] = 1
            
            episode_actions.append(action_)
            
            episode_rewards.append(reward)
            if done:
                # Calculate sum reward
                episode_rewards_sum = np.sum(episode_rewards)
                
                allRewards.append(episode_rewards_sum)
                
                total_rewards = np.sum(allRewards)
                
                # Mean reward
                mean_reward = np.divide(total_rewards, episode+1)
                
                
                maximumRewardRecorded = np.amax(allRewards)
                
                print("==========================================")
                print("Episode: ", episode)
                print("Reward: ", episode_rewards_sum)
                print("Mean Reward", mean_reward)
                print("Max reward so far: ", maximumRewardRecorded)
                
                # Calculate discounted reward
                discounted_episode_rewards = discount_and_normalize_rewards(episode_rewards)
                                
                # Feedforward, gradient and backpropagation
                loss_, _ = sess.run([loss, train_opt], feed_dict={input_: np.vstack(np.array(episode_states)),
                                                                 actions: np.vstack(np.array(episode_actions)),
                                                                 discounted_episode_rewards_: discounted_episode_rewards 
                                                                })
                
 
                                                                 
                # Write TF Summaries
                summary = sess.run(write_op, feed_dict={input_: np.vstack(np.array(episode_states)),
                                                                 actions: np.vstack(np.array(episode_actions)),
                                                                 discounted_episode_rewards_: discounted_episode_rewards,
                                                                    mean_reward_: mean_reward
                                                                })
                
               
                writer.add_summary(summary, episode)
                writer.flush()
                
            
                
                # Reset the transition stores
                episode_states, episode_actions, episode_rewards = [],[],[]
                
                break
            
            state = new_state
        
        # Save Model
        if episode % 100 == 0:
            saver.save(sess, "./models/model.ckpt")
            print("Model saved")
# Out:
# Streaming output truncated to the last 5000 lines.
# ==========================================
# Episode:  2
# Reward:  58.0
# Mean Reward 28.666666666666668
# Max reward so far:  58.0
# ==========================================
# Episode:  3
# Reward:  17.0
# Mean Reward 25.75
# Max reward so far:  58.0
# ==========================================
# Episode:  4
# Reward:  15.0
# Mean Reward 23.6
# Max reward so far:  58.0
# ==========================================
# Episode:  5
# Reward:  13.0
# Mean Reward 21.833333333333332
# Max reward so far:  58.0
# ==========================================
# Episode:  6
# Reward:  18.0
# Mean Reward 21.285714285714285
# Max reward so far:  58.0
# ==========================================
# Episode:  7
# Reward:  16.0
# Mean Reward 20.625
# Max reward so far:  58.0
# ==========================================
# Episode:  8
# Reward:  22.0
# Mean Reward 20.77777777777778
# Max reward so far:  58.0
# ==========================================
# Episode:  9
# Reward:  31.0
# Mean Reward 21.8
# Max reward so far:  58.0
# ==========================================
# Episode:  10
# Reward:  52.0
# Mean Reward 24.545454545454547
# Max reward so far:  58.0
# ==========================================
# Episode:  11
# Reward:  9.0
# Mean Reward 23.25
# Max reward so far:  58.0
# ==========================================
# Episode:  12
# Reward:  29.0
# Mean Reward 23.692307692307693
# Max reward so far:  58.0
# ==========================================
# Episode:  13
# Reward:  16.0
# Mean Reward 23.142857142857142
# Max reward so far:  58.0
# ==========================================
# Episode:  14
# Reward:  12.0
# Mean Reward 22.4
# Max reward so far:  58.0
# ==========================================
# Episode:  15
# Reward:  19.0
# Mean Reward 22.1875
# Max reward so far:  58.0
# ==========================================
# Episode:  16
# Reward:  11.0
# Mean Reward 21.529411764705884
# Max reward so far:  58.0
# ==========================================
# Episode:  17
# Reward:  12.0
# Mean Reward 21.0
# Max reward so far:  58.0
# ==========================================
# Episode:  18
# Reward:  12.0
# Mean Reward 20.526315789473685
# Max reward so far:  58.0
# ==========================================
# Episode:  19
# Reward:  31.0
# Mean Reward 21.05
# Max reward so far:  58.0
# ==========================================
# Episode:  20
# Reward:  42.0
# Mean Reward 22.047619047619047
# Max reward so far:  58.0
# ==========================================
# Episode:  21
# Reward:  12.0
# Mean Reward 21.59090909090909
# Max reward so far:  58.0
# ==========================================
# Episode:  22
# Reward:  10.0
# Mean Reward 21.08695652173913
# Max reward so far:  58.0
# ==========================================
# Episode:  23
# Reward:  22.0
# Mean Reward 21.125
# Max reward so far:  58.0
# ==========================================
# Episode:  24
# Reward:  19.0
# Mean Reward 21.04
# Max reward so far:  58.0
# ==========================================
# Episode:  25
# Reward:  13.0
# Mean Reward 20.73076923076923
# Max reward so far:  58.0
# ==========================================
# Episode:  26
# Reward:  19.0
# Mean Reward 20.666666666666668
# Max reward so far:  58.0
# ==========================================
# Episode:  27
# Reward:  14.0
# Mean Reward 20.428571428571427
# Max reward so far:  58.0
# ==========================================
# Episode:  28
# Reward:  18.0
# Mean Reward 20.344827586206897
# Max reward so far:  58.0
# ==========================================
# Episode:  29
# Reward:  12.0
# Mean Reward 20.066666666666666
# Max reward so far:  58.0
# ==========================================
# Episode:  30
# Reward:  9.0
# Mean Reward 19.70967741935484
# Max reward so far:  58.0
# ==========================================
# Episode:  31
# Reward:  13.0
# Mean Reward 19.5
# Max reward so far:  58.0
# ==========================================
# Episode:  32
# Reward:  13.0
# Mean Reward 19.303030303030305
# Max reward so far:  58.0
# ==========================================
# Episode:  33
# Reward:  26.0
# Mean Reward 19.5
# Max reward so far:  58.0
# ==========================================
# Episode:  34
# Reward:  21.0
# Mean Reward 19.542857142857144
# Max reward so far:  58.0
# ==========================================
# Episode:  35
# Reward:  9.0
# Mean Reward 19.25
# Max reward so far:  58.0
# ==========================================
# Episode:  36
# Reward:  11.0
# Mean Reward 19.027027027027028
# Max reward so far:  58.0
# ==========================================
# Episode:  37
# Reward:  12.0
# Mean Reward 18.842105263157894
# Max reward so far:  58.0
# ==========================================
# Episode:  38
# Reward:  14.0
# Mean Reward 18.71794871794872
# Max reward so far:  58.0
# ==========================================
# Episode:  39
# Reward:  29.0
# Mean Reward 18.975
# Max reward so far:  58.0
# ==========================================
# Episode:  40
# Reward:  26.0
# Mean Reward 19.146341463414632
# Max reward so far:  58.0
# ==========================================
# Episode:  41
# Reward:  30.0
# Mean Reward 19.404761904761905
# Max reward so far:  58.0
# ==========================================
# Episode:  42
# Reward:  21.0
# Mean Reward 19.441860465116278
# Max reward so far:  58.0
# ==========================================
# Episode:  43
# Reward:  22.0
# Mean Reward 19.5
# Max reward so far:  58.0
# ==========================================
# Episode:  44
# Reward:  22.0
# Mean Reward 19.555555555555557
# Max reward so far:  58.0
# ==========================================
# Episode:  45
# Reward:  13.0
# Mean Reward 19.41304347826087
# Max reward so far:  58.0
# ==========================================
# Episode:  46
# Reward:  18.0
# Mean Reward 19.382978723404257
# Max reward so far:  58.0
# ==========================================
# Episode:  47
# Reward:  15.0
# Mean Reward 19.291666666666668
# Max reward so far:  58.0
# ==========================================
# Episode:  48
# Reward:  15.0
# Mean Reward 19.20408163265306
# Max reward so far:  58.0
# ==========================================
# Episode:  49
# Reward:  15.0
# Mean Reward 19.12
# Max reward so far:  58.0
# ==========================================
# Episode:  50
# Reward:  15.0
# Mean Reward 19.03921568627451
# Max reward so far:  58.0
# ==========================================
# Episode:  51
# Reward:  15.0
# Mean Reward 18.96153846153846
# Max reward so far:  58.0
# ==========================================
# Episode:  52
# Reward:  21.0
# Mean Reward 19.0
# Max reward so far:  58.0
# ==========================================
# Episode:  53
# Reward:  12.0
# Mean Reward 18.87037037037037
# Max reward so far:  58.0
# ==========================================
# Episode:  54
# Reward:  10.0
# Mean Reward 18.70909090909091
# Max reward so far:  58.0
# ==========================================
# Episode:  55
# Reward:  9.0
# Mean Reward 18.535714285714285
# Max reward so far:  58.0
# ==========================================
# Episode:  56
# Reward:  18.0
# Mean Reward 18.526315789473685
# Max reward so far:  58.0
# ==========================================
# Episode:  57
# Reward:  16.0
# Mean Reward 18.482758620689655
# Max reward so far:  58.0
# ==========================================
# Episode:  58
# Reward:  10.0
# Mean Reward 18.338983050847457
# Max reward so far:  58.0
# ==========================================
# Episode:  59
# Reward:  28.0
# Mean Reward 18.5
# Max reward so far:  58.0
# ==========================================
# Episode:  60
# Reward:  12.0
# Mean Reward 18.39344262295082
# Max reward so far:  58.0
# ==========================================
# Episode:  61
# Reward:  26.0
# Mean Reward 18.516129032258064
# Max reward so far:  58.0
# ==========================================
# Episode:  62
# Reward:  9.0
# Mean Reward 18.365079365079364
# Max reward so far:  58.0
# ==========================================
# Episode:  63
# Reward:  14.0
# Mean Reward 18.296875
# Max reward so far:  58.0
# ==========================================
# Episode:  64
# Reward:  16.0
# Mean Reward 18.26153846153846
# Max reward so far:  58.0
# ==========================================
# Episode:  65
# Reward:  17.0
# Mean Reward 18.242424242424242
# Max reward so far:  58.0
# ==========================================
# Episode:  66
# Reward:  18.0
# Mean Reward 18.238805970149254
# Max reward so far:  58.0
# ==========================================
# Episode:  67
# Reward:  13.0
# Mean Reward 18.16176470588235
# Max reward so far:  58.0
# ==========================================
# Episode:  68
# Reward:  10.0
# Mean Reward 18.043478260869566
# Max reward so far:  58.0
# ==========================================
# Episode:  69
# Reward:  30.0
# Mean Reward 18.214285714285715
# Max reward so far:  58.0
# ==========================================
# Episode:  70
# Reward:  12.0
# Mean Reward 18.12676056338028
# Max reward so far:  58.0
# ==========================================
# Episode:  71
# Reward:  11.0
# Mean Reward 18.02777777777778
# Max reward so far:  58.0
# ==========================================
# Episode:  72
# Reward:  25.0
# Mean Reward 18.123287671232877
# Max reward so far:  58.0
# ==========================================
# Episode:  73
# Reward:  27.0
# Mean Reward 18.243243243243242
# Max reward so far:  58.0
# ==========================================
# Episode:  74
# Reward:  18.0
# Mean Reward 18.24
# Max reward so far:  58.0
# ==========================================
# Episode:  75
# Reward:  13.0
# Mean Reward 18.17105263157895
# Max reward so far:  58.0
# ==========================================
# Episode:  76
# Reward:  14.0
# Mean Reward 18.116883116883116
# Max reward so far:  58.0
# ==========================================
# Episode:  77
# Reward:  19.0
# Mean Reward 18.128205128205128
# Max reward so far:  58.0
# ==========================================
# Episode:  78
# Reward:  23.0
# Mean Reward 18.189873417721518
# Max reward so far:  58.0
# ==========================================
# Episode:  79
# Reward:  17.0
# Mean Reward 18.175
# Max reward so far:  58.0
# ==========================================
# Episode:  80
# Reward:  12.0
# Mean Reward 18.098765432098766
# Max reward so far:  58.0
# ==========================================
# Episode:  81
# Reward:  18.0
# Mean Reward 18.097560975609756
# Max reward so far:  58.0
# ==========================================
# Episode:  82
# Reward:  27.0
# Mean Reward 18.204819277108435
# Max reward so far:  58.0
# ==========================================
# Episode:  83
# Reward:  23.0
# Mean Reward 18.261904761904763
# Max reward so far:  58.0
# ==========================================
# Episode:  84
# Reward:  12.0
# Mean Reward 18.188235294117646
# Max reward so far:  58.0
# ==========================================
# Episode:  85
# Reward:  11.0
# Mean Reward 18.1046511627907
# Max reward so far:  58.0
# ==========================================
# Episode:  86
# Reward:  11.0
# Mean Reward 18.022988505747126
# Max reward so far:  58.0
# ==========================================
# Episode:  87
# Reward:  11.0
# Mean Reward 17.943181818181817
# Max reward so far:  58.0
# ==========================================
# Episode:  88
# Reward:  25.0
# Mean Reward 18.02247191011236
# Max reward so far:  58.0
# ==========================================
# Episode:  89
# Reward:  50.0
# Mean Reward 18.377777777777776
# Max reward so far:  58.0
# ==========================================
# Episode:  90
# Reward:  12.0
# Mean Reward 18.307692307692307
# Max reward so far:  58.0
# ==========================================
# Episode:  91
# Reward:  11.0
# Mean Reward 18.22826086956522
# Max reward so far:  58.0
# ==========================================
# Episode:  92
# Reward:  13.0
# Mean Reward 18.172043010752688
# Max reward so far:  58.0
# ==========================================
# Episode:  93
# Reward:  53.0
# Mean Reward 18.54255319148936
# Max reward so far:  58.0
# ==========================================
# Episode:  94
# Reward:  13.0
# Mean Reward 18.48421052631579
# Max reward so far:  58.0
# ==========================================
# Episode:  95
# Reward:  9.0
# Mean Reward 18.385416666666668
# Max reward so far:  58.0
# ==========================================
# Episode:  96
# Reward:  19.0
# Mean Reward 18.391752577319586
# Max reward so far:  58.0
# ==========================================
# Episode:  97
# Reward:  19.0
# Mean Reward 18.397959183673468
# Max reward so far:  58.0
# ==========================================
# Episode:  98
# Reward:  26.0
# Mean Reward 18.474747474747474
# Max reward so far:  58.0
# ==========================================
# Episode:  99
# Reward:  17.0
# Mean Reward 18.46
# Max reward so far:  58.0
# ==========================================
# Episode:  100
# Reward:  16.0
# Mean Reward 18.435643564356436
# Max reward so far:  58.0
# Model saved
# ==========================================
# Episode:  101
# Reward:  14.0
# Mean Reward 18.392156862745097
# Max reward so far:  58.0
# ==========================================
# Episode:  102
# Reward:  42.0
# Mean Reward 18.62135922330097
# Max reward so far:  58.0
# ==========================================
# Episode:  103
# Reward:  11.0
# Mean Reward 18.548076923076923
# Max reward so far:  58.0
# ==========================================
# Episode:  104
# Reward:  16.0
# Mean Reward 18.523809523809526
# Max reward so far:  58.0
# ==========================================
# Episode:  105
# Reward:  28.0
# Mean Reward 18.61320754716981
# Max reward so far:  58.0
# ==========================================
# Episode:  106
# Reward:  20.0
# Mean Reward 18.626168224299064
# Max reward so far:  58.0
# ==========================================
# Episode:  107
# Reward:  15.0
# Mean Reward 18.59259259259259
# Max reward so far:  58.0
# ==========================================
# Episode:  108
# Reward:  27.0
# Mean Reward 18.6697247706422
# Max reward so far:  58.0
# ==========================================
# Episode:  109
# Reward:  26.0
# Mean Reward 18.736363636363638
# Max reward so far:  58.0
# ==========================================
# Episode:  110
# Reward:  23.0
# Mean Reward 18.774774774774773
# Max reward so far:  58.0
# ==========================================
# Episode:  111
# Reward:  21.0
# Mean Reward 18.794642857142858
# Max reward so far:  58.0
# ==========================================
# Episode:  112
# Reward:  22.0
# Mean Reward 18.82300884955752
# Max reward so far:  58.0
# ==========================================
# Episode:  113
# Reward:  14.0
# Mean Reward 18.780701754385966
# Max reward so far:  58.0
# ==========================================
# Episode:  114
# Reward:  21.0
# Mean Reward 18.8
# Max reward so far:  58.0
# ==========================================
# Episode:  115
# Reward:  32.0
# Mean Reward 18.913793103448278
# Max reward so far:  58.0
# ==========================================
# Episode:  116
# Reward:  15.0
# Mean Reward 18.88034188034188
# Max reward so far:  58.0
# ==========================================
# Episode:  117
# Reward:  38.0
# Mean Reward 19.04237288135593
# Max reward so far:  58.0
# ==========================================
# Episode:  118
# Reward:  37.0
# Mean Reward 19.19327731092437
# Max reward so far:  58.0
# ==========================================
# Episode:  119
# Reward:  28.0
# Mean Reward 19.266666666666666
# Max reward so far:  58.0
# ==========================================
# Episode:  120
# Reward:  26.0
# Mean Reward 19.322314049586776
# Max reward so far:  58.0
# ==========================================
# Episode:  121
# Reward:  30.0
# Mean Reward 19.40983606557377
# Max reward so far:  58.0
# ==========================================
# Episode:  122
# Reward:  18.0
# Mean Reward 19.398373983739837
# Max reward so far:  58.0
# ==========================================
# Episode:  123
# Reward:  20.0
# Mean Reward 19.403225806451612
# Max reward so far:  58.0
# ==========================================
# Episode:  124
# Reward:  13.0
# Mean Reward 19.352
# Max reward so far:  58.0
# ==========================================
# Episode:  125
# Reward:  32.0
# Mean Reward 19.452380952380953
# Max reward so far:  58.0
# ==========================================
# Episode:  126
# Reward:  13.0
# Mean Reward 19.401574803149607
# Max reward so far:  58.0
# ==========================================
# Episode:  127
# Reward:  51.0
# Mean Reward 19.6484375
# Max reward so far:  58.0
# ==========================================
# Episode:  128
# Reward:  20.0
# Mean Reward 19.651162790697676
# Max reward so far:  58.0
# ==========================================
# Episode:  129
# Reward:  20.0
# Mean Reward 19.653846153846153
# Max reward so far:  58.0
# ==========================================
# Episode:  130
# Reward:  21.0
# Mean Reward 19.66412213740458
# Max reward so far:  58.0
# ==========================================
# Episode:  131
# Reward:  12.0
# Mean Reward 19.606060606060606
# Max reward so far:  58.0
# ==========================================
# Episode:  132
# Reward:  12.0
# Mean Reward 19.548872180451127
# Max reward so far:  58.0
# ==========================================
# Episode:  133
# Reward:  31.0
# Mean Reward 19.634328358208954
# Max reward so far:  58.0
# ==========================================
# Episode:  134
# Reward:  16.0
# Mean Reward 19.607407407407408
# Max reward so far:  58.0
# ==========================================
# Episode:  135
# Reward:  25.0
# Mean Reward 19.647058823529413
# Max reward so far:  58.0
# ==========================================
# Episode:  136
# Reward:  17.0
# Mean Reward 19.62773722627737
# Max reward so far:  58.0
# ==========================================
# Episode:  137
# Reward:  29.0
# Mean Reward 19.695652173913043
# Max reward so far:  58.0
# ==========================================
# Episode:  138
# Reward:  22.0
# Mean Reward 19.712230215827336
# Max reward so far:  58.0
# ==========================================
# Episode:  139
# Reward:  21.0
# Mean Reward 19.72142857142857
# Max reward so far:  58.0
# ==========================================
# Episode:  140
# Reward:  21.0
# Mean Reward 19.73049645390071
# Max reward so far:  58.0
# ==========================================
# Episode:  141
# Reward:  34.0
# Mean Reward 19.830985915492956
# Max reward so far:  58.0
# ==========================================
# Episode:  142
# Reward:  31.0
# Mean Reward 19.90909090909091
# Max reward so far:  58.0
# ==========================================
# Episode:  143
# Reward:  29.0
# Mean Reward 19.97222222222222
# Max reward so far:  58.0
# ==========================================
# Episode:  144
# Reward:  16.0
# Mean Reward 19.944827586206898
# Max reward so far:  58.0
# ==========================================
# Episode:  145
# Reward:  28.0
# Mean Reward 20.0
# Max reward so far:  58.0
# ==========================================
# Episode:  146
# Reward:  66.0
# Mean Reward 20.312925170068027
# Max reward so far:  66.0
# ==========================================
# Episode:  147
# Reward:  31.0
# Mean Reward 20.385135135135137
# Max reward so far:  66.0
# ==========================================
# Episode:  148
# Reward:  32.0
# Mean Reward 20.463087248322147
# Max reward so far:  66.0
# ==========================================
# Episode:  149
# Reward:  36.0
# Mean Reward 20.566666666666666
# Max reward so far:  66.0
# ==========================================
# Episode:  150
# Reward:  12.0
# Mean Reward 20.509933774834437
# Max reward so far:  66.0
# ==========================================
# Episode:  151
# Reward:  13.0
# Mean Reward 20.460526315789473
# Max reward so far:  66.0
# ==========================================
# Episode:  152
# Reward:  14.0
# Mean Reward 20.41830065359477
# Max reward so far:  66.0
# ==========================================
# Episode:  153
# Reward:  58.0
# Mean Reward 20.662337662337663
# Max reward so far:  66.0
# ==========================================
# Episode:  154
# Reward:  20.0
# Mean Reward 20.65806451612903
# Max reward so far:  66.0
# ==========================================
# Episode:  155
# Reward:  11.0
# Mean Reward 20.596153846153847
# Max reward so far:  66.0
# ==========================================
# Episode:  156
# Reward:  16.0
# Mean Reward 20.56687898089172
# Max reward so far:  66.0
# ==========================================
# Episode:  157
# Reward:  26.0
# Mean Reward 20.60126582278481
# Max reward so far:  66.0
# ==========================================
# Episode:  158
# Reward:  70.0
# Mean Reward 20.91194968553459
# Max reward so far:  70.0
# ==========================================
# Episode:  159
# Reward:  13.0
# Mean Reward 20.8625
# Max reward so far:  70.0
# ==========================================
# Episode:  160
# Reward:  17.0
# Mean Reward 20.838509316770185
# Max reward so far:  70.0
# ==========================================
# Episode:  161
# Reward:  14.0
# Mean Reward 20.796296296296298
# Max reward so far:  70.0
# ==========================================
# Episode:  162
# Reward:  30.0
# Mean Reward 20.85276073619632
# Max reward so far:  70.0
# ==========================================
# Episode:  163
# Reward:  33.0
# Mean Reward 20.926829268292682
# Max reward so far:  70.0
# ==========================================
# Episode:  164
# Reward:  15.0
# Mean Reward 20.89090909090909
# Max reward so far:  70.0
# ==========================================
# Episode:  165
# Reward:  26.0
# Mean Reward 20.92168674698795
# Max reward so far:  70.0
# ==========================================
# Episode:  166
# Reward:  16.0
# Mean Reward 20.892215568862277
# Max reward so far:  70.0
# ==========================================
# Episode:  167
# Reward:  33.0
# Mean Reward 20.964285714285715
# Max reward so far:  70.0
# ==========================================
# Episode:  168
# Reward:  48.0
# Mean Reward 21.124260355029588
# Max reward so far:  70.0
# ==========================================
# Episode:  169
# Reward:  73.0
# Mean Reward 21.429411764705883
# Max reward so far:  73.0
# ==========================================
# Episode:  170
# Reward:  90.0
# Mean Reward 21.830409356725145
# Max reward so far:  90.0
# ==========================================
# Episode:  171
# Reward:  51.0
# Mean Reward 22.0
# Max reward so far:  90.0
# ==========================================
# Episode:  172
# Reward:  18.0
# Mean Reward 21.976878612716764
# Max reward so far:  90.0
# ==========================================
# Episode:  173
# Reward:  10.0
# Mean Reward 21.908045977011493
# Max reward so far:  90.0
# ==========================================
# Episode:  174
# Reward:  19.0
# Mean Reward 21.89142857142857
# Max reward so far:  90.0
# ==========================================
# Episode:  175
# Reward:  46.0
# Mean Reward 22.02840909090909
# Max reward so far:  90.0
# ==========================================
# Episode:  176
# Reward:  45.0
# Mean Reward 22.15819209039548
# Max reward so far:  90.0
# ==========================================
# Episode:  177
# Reward:  29.0
# Mean Reward 22.196629213483146
# Max reward so far:  90.0
# ==========================================
# Episode:  178
# Reward:  30.0
# Mean Reward 22.24022346368715
# Max reward so far:  90.0
# ==========================================
# Episode:  179
# Reward:  42.0
# Mean Reward 22.35
# Max reward so far:  90.0
# ==========================================
# Episode:  180
# Reward:  16.0
# Mean Reward 22.314917127071823
# Max reward so far:  90.0
# ==========================================
# Episode:  181
# Reward:  58.0
# Mean Reward 22.51098901098901
# Max reward so far:  90.0
# ==========================================
# Episode:  182
# Reward:  59.0
# Mean Reward 22.7103825136612
# Max reward so far:  90.0
# ==========================================
# Episode:  183
# Reward:  13.0
# Mean Reward 22.657608695652176
# Max reward so far:  90.0
# ==========================================
# Episode:  184
# Reward:  43.0
# Mean Reward 22.767567567567568
# Max reward so far:  90.0
# ==========================================
# Episode:  185
# Reward:  47.0
# Mean Reward 22.897849462365592
# Max reward so far:  90.0
# ==========================================
# Episode:  186
# Reward:  31.0
# Mean Reward 22.941176470588236
# Max reward so far:  90.0
# ==========================================
# Episode:  187
# Reward:  15.0
# Mean Reward 22.898936170212767
# Max reward so far:  90.0
# ==========================================
# Episode:  188
# Reward:  17.0
# Mean Reward 22.867724867724867
# Max reward so far:  90.0
# ==========================================
# Episode:  189
# Reward:  12.0
# Mean Reward 22.810526315789474
# Max reward so far:  90.0
# ==========================================
# Episode:  190
# Reward:  11.0
# Mean Reward 22.74869109947644
# Max reward so far:  90.0
# ==========================================
# Episode:  191
# Reward:  20.0
# Mean Reward 22.734375
# Max reward so far:  90.0
# ==========================================
# Episode:  192
# Reward:  35.0
# Mean Reward 22.797927461139896
# Max reward so far:  90.0
# ==========================================
# Episode:  193
# Reward:  25.0
# Mean Reward 22.809278350515463
# Max reward so far:  90.0
# ==========================================
# Episode:  194
# Reward:  17.0
# Mean Reward 22.77948717948718
# Max reward so far:  90.0
# ==========================================
# Episode:  195
# Reward:  10.0
# Mean Reward 22.714285714285715
# Max reward so far:  90.0
# ==========================================
# Episode:  196
# Reward:  41.0
# Mean Reward 22.80710659898477
# Max reward so far:  90.0
# ==========================================
# Episode:  197
# Reward:  22.0
# Mean Reward 22.803030303030305
# Max reward so far:  90.0
# ==========================================
# Episode:  198
# Reward:  31.0
# Mean Reward 22.844221105527637
# Max reward so far:  90.0
# ==========================================
# Episode:  199
# Reward:  48.0
# Mean Reward 22.97
# Max reward so far:  90.0
# ==========================================
# Episode:  200
# Reward:  36.0
# Mean Reward 23.034825870646767
# Max reward so far:  90.0
# Model saved
# ==========================================
# Episode:  201
# Reward:  55.0
# Mean Reward 23.193069306930692
# Max reward so far:  90.0
# ==========================================
# Episode:  202
# Reward:  26.0
# Mean Reward 23.20689655172414
# Max reward so far:  90.0
# ==========================================
# Episode:  203
# Reward:  46.0
# Mean Reward 23.318627450980394
# Max reward so far:  90.0
# ==========================================
# Episode:  204
# Reward:  12.0
# Mean Reward 23.26341463414634
# Max reward so far:  90.0
# ==========================================
# Episode:  205
# Reward:  21.0
# Mean Reward 23.25242718446602
# Max reward so far:  90.0
# ==========================================
# Episode:  206
# Reward:  14.0
# Mean Reward 23.207729468599034
# Max reward so far:  90.0
# ==========================================
# Episode:  207
# Reward:  34.0
# Mean Reward 23.259615384615383
# Max reward so far:  90.0
# ==========================================
# Episode:  208
# Reward:  19.0
# Mean Reward 23.239234449760765
# Max reward so far:  90.0
# ==========================================
# Episode:  209
# Reward:  26.0
# Mean Reward 23.252380952380953
# Max reward so far:  90.0
# ==========================================
# Episode:  210
# Reward:  90.0
# Mean Reward 23.56872037914692
# Max reward so far:  90.0
# ==========================================
# Episode:  211
# Reward:  32.0
# Mean Reward 23.608490566037737
# Max reward so far:  90.0
# ==========================================
# Episode:  212
# Reward:  22.0
# Mean Reward 23.600938967136152
# Max reward so far:  90.0
# ==========================================
# Episode:  213
# Reward:  43.0
# Mean Reward 23.69158878504673
# Max reward so far:  90.0
# ==========================================
# Episode:  214
# Reward:  15.0
# Mean Reward 23.651162790697676
# Max reward so far:  90.0
# ==========================================
# Episode:  215
# Reward:  25.0
# Mean Reward 23.65740740740741
# Max reward so far:  90.0
# ==========================================
# Episode:  216
# Reward:  31.0
# Mean Reward 23.691244239631338
# Max reward so far:  90.0
# ==========================================
# Episode:  217
# Reward:  15.0
# Mean Reward 23.65137614678899
# Max reward so far:  90.0
# ==========================================
# Episode:  218
# Reward:  37.0
# Mean Reward 23.71232876712329
# Max reward so far:  90.0
# ==========================================
# Episode:  219
# Reward:  13.0
# Mean Reward 23.663636363636364
# Max reward so far:  90.0
# ==========================================
# Episode:  220
# Reward:  35.0
# Mean Reward 23.714932126696834
# Max reward so far:  90.0
# ==========================================
# Episode:  221
# Reward:  44.0
# Mean Reward 23.806306306306308
# Max reward so far:  90.0
# ==========================================
# Episode:  222
# Reward:  13.0
# Mean Reward 23.757847533632287
# Max reward so far:  90.0
# ==========================================
# Episode:  223
# Reward:  30.0
# Mean Reward 23.785714285714285
# Max reward so far:  90.0
# ==========================================
# Episode:  224
# Reward:  27.0
# Mean Reward 23.8
# Max reward so far:  90.0
# ==========================================
# Episode:  225
# Reward:  45.0
# Mean Reward 23.893805309734514
# Max reward so far:  90.0
# ==========================================
# Episode:  226
# Reward:  32.0
# Mean Reward 23.929515418502202
# Max reward so far:  90.0
# ==========================================
# Episode:  227
# Reward:  10.0
# Mean Reward 23.86842105263158
# Max reward so far:  90.0
# ==========================================
# Episode:  228
# Reward:  12.0
# Mean Reward 23.816593886462883
# Max reward so far:  90.0
# ==========================================
# Episode:  229
# Reward:  21.0
# Mean Reward 23.804347826086957
# Max reward so far:  90.0
# ==========================================
# Episode:  230
# Reward:  20.0
# Mean Reward 23.78787878787879
# Max reward so far:  90.0
# ==========================================
# Episode:  231
# Reward:  14.0
# Mean Reward 23.745689655172413
# Max reward so far:  90.0
# ==========================================
# Episode:  232
# Reward:  36.0
# Mean Reward 23.798283261802574
# Max reward so far:  90.0
# ==========================================
# Episode:  233
# Reward:  24.0
# Mean Reward 23.799145299145298
# Max reward so far:  90.0
# ==========================================
# Episode:  234
# Reward:  61.0
# Mean Reward 23.95744680851064
# Max reward so far:  90.0
# ==========================================
# Episode:  235
# Reward:  75.0
# Mean Reward 24.173728813559322
# Max reward so far:  90.0
# ==========================================
# Episode:  236
# Reward:  26.0
# Mean Reward 24.18143459915612
# Max reward so far:  90.0
# ==========================================
# Episode:  237
# Reward:  19.0
# Mean Reward 24.159663865546218
# Max reward so far:  90.0
# ==========================================
# Episode:  238
# Reward:  21.0
# Mean Reward 24.14644351464435
# Max reward so far:  90.0
# ==========================================
# Episode:  239
# Reward:  15.0
# Mean Reward 24.108333333333334
# Max reward so far:  90.0
# ==========================================
# Episode:  240
# Reward:  58.0
# Mean Reward 24.24896265560166
# Max reward so far:  90.0
# ==========================================
# Episode:  241
# Reward:  70.0
# Mean Reward 24.43801652892562
# Max reward so far:  90.0
# ==========================================
# Episode:  242
# Reward:  21.0
# Mean Reward 24.4238683127572
# Max reward so far:  90.0
# ==========================================
# Episode:  243
# Reward:  21.0
# Mean Reward 24.40983606557377
# Max reward so far:  90.0
# ==========================================
# Episode:  244
# Reward:  19.0
# Mean Reward 24.387755102040817
# Max reward so far:  90.0
# ==========================================
# Episode:  245
# Reward:  16.0
# Mean Reward 24.353658536585368
# Max reward so far:  90.0
# ==========================================
# Episode:  246
# Reward:  18.0
# Mean Reward 24.327935222672064
# Max reward so far:  90.0
# ==========================================
# Episode:  247
# Reward:  17.0
# Mean Reward 24.298387096774192
# Max reward so far:  90.0
# ==========================================
# Episode:  248
# Reward:  31.0
# Mean Reward 24.325301204819276
# Max reward so far:  90.0
# ==========================================
# Episode:  249
# Reward:  13.0
# Mean Reward 24.28
# Max reward so far:  90.0
# ==========================================
# Episode:  250
# Reward:  13.0
# Mean Reward 24.235059760956176
# Max reward so far:  90.0
# ==========================================
# Episode:  251
# Reward:  48.0
# Mean Reward 24.32936507936508
# Max reward so far:  90.0
# ==========================================
# Episode:  252
# Reward:  57.0
# Mean Reward 24.458498023715414
# Max reward so far:  90.0
# ==========================================
# Episode:  253
# Reward:  32.0
# Mean Reward 24.488188976377952
# Max reward so far:  90.0
# ==========================================
# Episode:  254
# Reward:  24.0
# Mean Reward 24.48627450980392
# Max reward so far:  90.0
# ==========================================
# Episode:  255
# Reward:  29.0
# Mean Reward 24.50390625
# Max reward so far:  90.0
# ==========================================
# Episode:  256
# Reward:  36.0
# Mean Reward 24.54863813229572
# Max reward so far:  90.0
# ==========================================
# Episode:  257
# Reward:  12.0
# Mean Reward 24.5
# Max reward so far:  90.0
# ==========================================
# Episode:  258
# Reward:  38.0
# Mean Reward 24.55212355212355
# Max reward so far:  90.0
# ==========================================
# Episode:  259
# Reward:  17.0
# Mean Reward 24.523076923076925
# Max reward so far:  90.0
# ==========================================
# Episode:  260
# Reward:  29.0
# Mean Reward 24.54022988505747
# Max reward so far:  90.0
# ==========================================
# Episode:  261
# Reward:  28.0
# Mean Reward 24.553435114503817
# Max reward so far:  90.0
# ==========================================
# Episode:  262
# Reward:  17.0
# Mean Reward 24.524714828897338
# Max reward so far:  90.0
# ==========================================
# Episode:  263
# Reward:  30.0
# Mean Reward 24.545454545454547
# Max reward so far:  90.0
# ==========================================
# Episode:  264
# Reward:  62.0
# Mean Reward 24.68679245283019
# Max reward so far:  90.0
# ==========================================
# Episode:  265
# Reward:  11.0
# Mean Reward 24.63533834586466
# Max reward so far:  90.0
# ==========================================
# Episode:  266
# Reward:  71.0
# Mean Reward 24.808988764044944
# Max reward so far:  90.0
# ==========================================
# Episode:  267
# Reward:  29.0
# Mean Reward 24.824626865671643
# Max reward so far:  90.0
# ==========================================
# Episode:  268
# Reward:  39.0
# Mean Reward 24.87732342007435
# Max reward so far:  90.0
# ==========================================
# Episode:  269
# Reward:  50.0
# Mean Reward 24.97037037037037
# Max reward so far:  90.0
# ==========================================
# Episode:  270
# Reward:  51.0
# Mean Reward 25.066420664206642
# Max reward so far:  90.0
# ==========================================
# Episode:  271
# Reward:  92.0
# Mean Reward 25.3125
# Max reward so far:  92.0
# ==========================================
# Episode:  272
# Reward:  16.0
# Mean Reward 25.278388278388277
# Max reward so far:  92.0
# ==========================================
# Episode:  273
# Reward:  23.0
# Mean Reward 25.27007299270073
# Max reward so far:  92.0
# ==========================================
# Episode:  274
# Reward:  23.0
# Mean Reward 25.26181818181818
# Max reward so far:  92.0
# ==========================================
# Episode:  275
# Reward:  17.0
# Mean Reward 25.231884057971016
# Max reward so far:  92.0
# ==========================================
# Episode:  276
# Reward:  13.0
# Mean Reward 25.187725631768952
# Max reward so far:  92.0
# ==========================================
# Episode:  277
# Reward:  25.0
# Mean Reward 25.18705035971223
# Max reward so far:  92.0
# ==========================================
# Episode:  278
# Reward:  20.0
# Mean Reward 25.168458781362006
# Max reward so far:  92.0
# ==========================================
# Episode:  279
# Reward:  23.0
# Mean Reward 25.160714285714285
# Max reward so far:  92.0
# ==========================================
# Episode:  280
# Reward:  63.0
# Mean Reward 25.295373665480426
# Max reward so far:  92.0
# ==========================================
# Episode:  281
# Reward:  39.0
# Mean Reward 25.343971631205672
# Max reward so far:  92.0
# ==========================================
# Episode:  282
# Reward:  20.0
# Mean Reward 25.325088339222614
# Max reward so far:  92.0
# ==========================================
# Episode:  283
# Reward:  10.0
# Mean Reward 25.27112676056338
# Max reward so far:  92.0
# ==========================================
# Episode:  284
# Reward:  28.0
# Mean Reward 25.280701754385966
# Max reward so far:  92.0
# ==========================================
# Episode:  285
# Reward:  25.0
# Mean Reward 25.27972027972028
# Max reward so far:  92.0
# ==========================================
# Episode:  286
# Reward:  66.0
# Mean Reward 25.421602787456447
# Max reward so far:  92.0
# ==========================================
# Episode:  287
# Reward:  23.0
# Mean Reward 25.413194444444443
# Max reward so far:  92.0
# ==========================================
# Episode:  288
# Reward:  33.0
# Mean Reward 25.439446366782008
# Max reward so far:  92.0
# ==========================================
# Episode:  289
# Reward:  18.0
# Mean Reward 25.413793103448278
# Max reward so far:  92.0
# ==========================================
# Episode:  290
# Reward:  35.0
# Mean Reward 25.446735395189002
# Max reward so far:  92.0
# ==========================================
# Episode:  291
# Reward:  27.0
# Mean Reward 25.45205479452055
# Max reward so far:  92.0
# ==========================================
# Episode:  292
# Reward:  22.0
# Mean Reward 25.440273037542664
# Max reward so far:  92.0
# ==========================================
# Episode:  293
# Reward:  48.0
# Mean Reward 25.517006802721088
# Max reward so far:  92.0
# ==========================================
# Episode:  294
# Reward:  12.0
# Mean Reward 25.471186440677965
# Max reward so far:  92.0
# ==========================================
# Episode:  295
# Reward:  14.0
# Mean Reward 25.43243243243243
# Max reward so far:  92.0
# ==========================================
# Episode:  296
# Reward:  17.0
# Mean Reward 25.404040404040405
# Max reward so far:  92.0
# ==========================================
# Episode:  297
# Reward:  55.0
# Mean Reward 25.503355704697988
# Max reward so far:  92.0
# ==========================================
# Episode:  298
# Reward:  29.0
# Mean Reward 25.51505016722408
# Max reward so far:  92.0
# ==========================================
# Episode:  299
# Reward:  41.0
# Mean Reward 25.566666666666666
# Max reward so far:  92.0
# ==========================================
# Episode:  300
# Reward:  45.0
# Mean Reward 25.631229235880397
# Max reward so far:  92.0
# Model saved
# ==========================================
# Episode:  301
# Reward:  72.0
# Mean Reward 25.78476821192053
# Max reward so far:  92.0
# ==========================================
# Episode:  302
# Reward:  13.0
# Mean Reward 25.742574257425744
# Max reward so far:  92.0
# ==========================================
# Episode:  303
# Reward:  33.0
# Mean Reward 25.76644736842105
# Max reward so far:  92.0
# ==========================================
# Episode:  304
# Reward:  37.0
# Mean Reward 25.80327868852459
# Max reward so far:  92.0
# ==========================================
# Episode:  305
# Reward:  19.0
# Mean Reward 25.781045751633986
# Max reward so far:  92.0
# ==========================================
# Episode:  306
# Reward:  22.0
# Mean Reward 25.76872964169381
# Max reward so far:  92.0
# ==========================================
# Episode:  307
# Reward:  20.0
# Mean Reward 25.75
# Max reward so far:  92.0
# ==========================================
# Episode:  308
# Reward:  27.0
# Mean Reward 25.754045307443366
# Max reward so far:  92.0
# ==========================================
# Episode:  309
# Reward:  13.0
# Mean Reward 25.712903225806453
# Max reward so far:  92.0
# ==========================================
# Episode:  310
# Reward:  11.0
# Mean Reward 25.665594855305468
# Max reward so far:  92.0
# ==========================================
# Episode:  311
# Reward:  74.0
# Mean Reward 25.82051282051282
# Max reward so far:  92.0
# ==========================================
# Episode:  312
# Reward:  46.0
# Mean Reward 25.884984025559106
# Max reward so far:  92.0
# ==========================================
# Episode:  313
# Reward:  26.0
# Mean Reward 25.88535031847134
# Max reward so far:  92.0
# ==========================================
# Episode:  314
# Reward:  43.0
# Mean Reward 25.93968253968254
# Max reward so far:  92.0
# ==========================================
# Episode:  315
# Reward:  43.0
# Mean Reward 25.99367088607595
# Max reward so far:  92.0
# ==========================================
# Episode:  316
# Reward:  57.0
# Mean Reward 26.09148264984227
# Max reward so far:  92.0
# ==========================================
# Episode:  317
# Reward:  26.0
# Mean Reward 26.09119496855346
# Max reward so far:  92.0
# ==========================================
# Episode:  318
# Reward:  31.0
# Mean Reward 26.106583072100314
# Max reward so far:  92.0
# ==========================================
# Episode:  319
# Reward:  48.0
# Mean Reward 26.175
# Max reward so far:  92.0
# ==========================================
# Episode:  320
# Reward:  14.0
# Mean Reward 26.13707165109034
# Max reward so far:  92.0
# ==========================================
# Episode:  321
# Reward:  12.0
# Mean Reward 26.093167701863354
# Max reward so far:  92.0
# ==========================================
# Episode:  322
# Reward:  37.0
# Mean Reward 26.126934984520123
# Max reward so far:  92.0
# ==========================================
# Episode:  323
# Reward:  25.0
# Mean Reward 26.123456790123456
# Max reward so far:  92.0
# ==========================================
# Episode:  324
# Reward:  28.0
# Mean Reward 26.12923076923077
# Max reward so far:  92.0
# ==========================================
# Episode:  325
# Reward:  30.0
# Mean Reward 26.141104294478527
# Max reward so far:  92.0
# ==========================================
# Episode:  326
# Reward:  56.0
# Mean Reward 26.232415902140673
# Max reward so far:  92.0
# ==========================================
# Episode:  327
# Reward:  31.0
# Mean Reward 26.246951219512194
# Max reward so far:  92.0
# ==========================================
# Episode:  328
# Reward:  43.0
# Mean Reward 26.29787234042553
# Max reward so far:  92.0
# ==========================================
# Episode:  329
# Reward:  99.0
# Mean Reward 26.51818181818182
# Max reward so far:  99.0
# ==========================================
# Episode:  330
# Reward:  63.0
# Mean Reward 26.628398791540786
# Max reward so far:  99.0
# ==========================================
# Episode:  331
# Reward:  11.0
# Mean Reward 26.58132530120482
# Max reward so far:  99.0
# ==========================================
# Episode:  332
# Reward:  34.0
# Mean Reward 26.603603603603602
# Max reward so far:  99.0
# ==========================================
# Episode:  333
# Reward:  47.0
# Mean Reward 26.664670658682635
# Max reward so far:  99.0
# ==========================================
# Episode:  334
# Reward:  19.0
# Mean Reward 26.64179104477612
# Max reward so far:  99.0
# ==========================================
# Episode:  335
# Reward:  140.0
# Mean Reward 26.979166666666668
# Max reward so far:  140.0
# ==========================================
# Episode:  336
# Reward:  13.0
# Mean Reward 26.937685459940653
# Max reward so far:  140.0
# ==========================================
# Episode:  337
# Reward:  18.0
# Mean Reward 26.911242603550296
# Max reward so far:  140.0
# ==========================================
# Episode:  338
# Reward:  27.0
# Mean Reward 26.911504424778762
# Max reward so far:  140.0
# ==========================================
# Episode:  339
# Reward:  87.0
# Mean Reward 27.08823529411765
# Max reward so far:  140.0
# ==========================================
# Episode:  340
# Reward:  106.0
# Mean Reward 27.319648093841643
# Max reward so far:  140.0
# ==========================================
# Episode:  341
# Reward:  19.0
# Mean Reward 27.295321637426902
# Max reward so far:  140.0
# ==========================================
# Episode:  342
# Reward:  17.0
# Mean Reward 27.26530612244898
# Max reward so far:  140.0
# ==========================================
# Episode:  343
# Reward:  20.0
# Mean Reward 27.24418604651163
# Max reward so far:  140.0
# ==========================================
# Episode:  344
# Reward:  63.0
# Mean Reward 27.347826086956523
# Max reward so far:  140.0
# ==========================================
# Episode:  345
# Reward:  72.0
# Mean Reward 27.476878612716764
# Max reward so far:  140.0
# ==========================================
# Episode:  346
# Reward:  36.0
# Mean Reward 27.501440922190202
# Max reward so far:  140.0
# ==========================================
# Episode:  347
# Reward:  33.0
# Mean Reward 27.517241379310345
# Max reward so far:  140.0
# ==========================================
# Episode:  348
# Reward:  34.0
# Mean Reward 27.535816618911173
# Max reward so far:  140.0
# ==========================================
# Episode:  349
# Reward:  62.0
# Mean Reward 27.634285714285713
# Max reward so far:  140.0
# ==========================================
# Episode:  350
# Reward:  24.0
# Mean Reward 27.623931623931625
# Max reward so far:  140.0
# ==========================================
# Episode:  351
# Reward:  64.0
# Mean Reward 27.727272727272727
# Max reward so far:  140.0
# ==========================================
# Episode:  352
# Reward:  25.0
# Mean Reward 27.71954674220963
# Max reward so far:  140.0
# ==========================================
# Episode:  353
# Reward:  56.0
# Mean Reward 27.79943502824859
# Max reward so far:  140.0
# ==========================================
# Episode:  354
# Reward:  15.0
# Mean Reward 27.76338028169014
# Max reward so far:  140.0
# ==========================================
# Episode:  355
# Reward:  168.0
# Mean Reward 28.15730337078652
# Max reward so far:  168.0
# ==========================================
# Episode:  356
# Reward:  88.0
# Mean Reward 28.324929971988794
# Max reward so far:  168.0
# ==========================================
# Episode:  357
# Reward:  42.0
# Mean Reward 28.363128491620113
# Max reward so far:  168.0
# ==========================================
# Episode:  358
# Reward:  78.0
# Mean Reward 28.501392757660167
# Max reward so far:  168.0
# ==========================================
# Episode:  359
# Reward:  60.0
# Mean Reward 28.58888888888889
# Max reward so far:  168.0
# ==========================================
# Episode:  360
# Reward:  147.0
# Mean Reward 28.916897506925206
# Max reward so far:  168.0
# ==========================================
# Episode:  361
# Reward:  27.0
# Mean Reward 28.91160220994475
# Max reward so far:  168.0
# ==========================================
# Episode:  362
# Reward:  54.0
# Mean Reward 28.980716253443525
# Max reward so far:  168.0
# ==========================================
# Episode:  363
# Reward:  17.0
# Mean Reward 28.947802197802197
# Max reward so far:  168.0
# ==========================================
# Episode:  364
# Reward:  98.0
# Mean Reward 29.136986301369863
# Max reward so far:  168.0
# ==========================================
# Episode:  365
# Reward:  36.0
# Mean Reward 29.15573770491803
# Max reward so far:  168.0
# ==========================================
# Episode:  366
# Reward:  14.0
# Mean Reward 29.114441416893733
# Max reward so far:  168.0
# ==========================================
# Episode:  367
# Reward:  40.0
# Mean Reward 29.144021739130434
# Max reward so far:  168.0
# ==========================================
# Episode:  368
# Reward:  44.0
# Mean Reward 29.18428184281843
# Max reward so far:  168.0
# ==========================================
# Episode:  369
# Reward:  55.0
# Mean Reward 29.254054054054055
# Max reward so far:  168.0
# ==========================================
# Episode:  370
# Reward:  170.0
# Mean Reward 29.63342318059299
# Max reward so far:  170.0
# ==========================================
# Episode:  371
# Reward:  55.0
# Mean Reward 29.701612903225808
# Max reward so far:  170.0
# ==========================================
# Episode:  372
# Reward:  66.0
# Mean Reward 29.798927613941018
# Max reward so far:  170.0
# ==========================================
# Episode:  373
# Reward:  46.0
# Mean Reward 29.842245989304814
# Max reward so far:  170.0
# ==========================================
# Episode:  374
# Reward:  92.0
# Mean Reward 30.008
# Max reward so far:  170.0
# ==========================================
# Episode:  375
# Reward:  33.0
# Mean Reward 30.01595744680851
# Max reward so far:  170.0
# ==========================================
# Episode:  376
# Reward:  27.0
# Mean Reward 30.007957559681696
# Max reward so far:  170.0
# ==========================================
# Episode:  377
# Reward:  24.0
# Mean Reward 29.99206349206349
# Max reward so far:  170.0
# ==========================================
# Episode:  378
# Reward:  44.0
# Mean Reward 30.029023746701846
# Max reward so far:  170.0
# ==========================================
# Episode:  379
# Reward:  37.0
# Mean Reward 30.04736842105263
# Max reward so far:  170.0
# ==========================================
# Episode:  380
# Reward:  128.0
# Mean Reward 30.304461942257216
# Max reward so far:  170.0
# ==========================================
# Episode:  381
# Reward:  170.0
# Mean Reward 30.670157068062828
# Max reward so far:  170.0
# ==========================================
# Episode:  382
# Reward:  23.0
# Mean Reward 30.650130548302872
# Max reward so far:  170.0
# ==========================================
# Episode:  383
# Reward:  24.0
# Mean Reward 30.6328125
# Max reward so far:  170.0
# ==========================================
# Episode:  384
# Reward:  76.0
# ...
# Max reward so far:  1073.0
# ==========================================
# Episode:  877
# Reward:  147.0
# Mean Reward 109.9874715261959
# Max reward so far:  1073.0
# ==========================================
# Episode:  878
# Reward:  163.0
# Mean Reward 110.04778156996586
# Max reward so far:  1073.0
# ==========================================
# Episode:  879
# Reward:  171.0
# Mean Reward 110.11704545454545
# Max reward so far:  1073.0
# ==========================================
# Episode:  880
# Reward:  145.0
# Mean Reward 110.1566401816118
# Max reward so far:  1073.0
# ==========================================
# Episode:  881
# Reward:  182.0
# Mean Reward 110.23809523809524
# Max reward so far:  1073.0
# ==========================================
# Episode:  882
# Reward:  134.0
# Mean Reward 110.26500566251416
# Max reward so far:  1073.0
# ==========================================
# Episode:  883
# Reward:  163.0
# Mean Reward 110.32466063348416
# Max reward so far:  1073.0
# ==========================================
# Episode:  884
# Reward:  128.0
# Mean Reward 110.34463276836158
# Max reward so far:  1073.0
# ==========================================
# Episode:  885
# Reward:  138.0
# Mean Reward 110.37584650112866
# Max reward so far:  1073.0
# ==========================================
# Episode:  886
# Reward:  139.0
# Mean Reward 110.40811724915446
# Max reward so far:  1073.0
# ==========================================
# Episode:  887
# Reward:  126.0
# Mean Reward 110.42567567567568
# Max reward so far:  1073.0
# ==========================================
# Episode:  888
# Reward:  129.0
# Mean Reward 110.44656917885264
# Max reward so far:  1073.0
# ==========================================
# Episode:  889
# Reward:  105.0
# Mean Reward 110.44044943820225
# Max reward so far:  1073.0
# ==========================================
# Episode:  890
# Reward:  138.0
# Mean Reward 110.47138047138047
# Max reward so far:  1073.0
# ==========================================
# Episode:  891
# Reward:  149.0
# Mean Reward 110.51457399103138
# Max reward so far:  1073.0
# ==========================================
# Episode:  892
# Reward:  130.0
# Mean Reward 110.5363941769317
# Max reward so far:  1073.0
# ==========================================
# Episode:  893
# Reward:  125.0
# Mean Reward 110.55257270693512
# Max reward so far:  1073.0
# ==========================================
# Episode:  894
# Reward:  77.0
# Mean Reward 110.51508379888269
# Max reward so far:  1073.0
# ==========================================
# Episode:  895
# Reward:  192.0
# Mean Reward 110.60602678571429
# Max reward so far:  1073.0
# ==========================================
# Episode:  896
# Reward:  128.0
# Mean Reward 110.62541806020067
# Max reward so far:  1073.0
# ==========================================
# Episode:  897
# Reward:  154.0
# Mean Reward 110.67371937639199
# Max reward so far:  1073.0
# ==========================================
# Episode:  898
# Reward:  129.0
# Mean Reward 110.69410456062292
# Max reward so far:  1073.0
# ==========================================
# Episode:  899
# Reward:  127.0
# Mean Reward 110.71222222222222
# Max reward so far:  1073.0
# ==========================================
# Episode:  900
# Reward:  50.0
# Mean Reward 110.64483906770255
# Max reward so far:  1073.0
# Model saved
# ==========================================
# Episode:  901
# Reward:  128.0
# Mean Reward 110.66407982261642
# Max reward so far:  1073.0
# ==========================================
# Episode:  902
# Reward:  236.0
# Mean Reward 110.80287929125139
# Max reward so far:  1073.0
# ==========================================
# Episode:  903
# Reward:  146.0
# Mean Reward 110.84181415929204
# Max reward so far:  1073.0
# ==========================================
# Episode:  904
# Reward:  148.0
# Mean Reward 110.8828729281768
# Max reward so far:  1073.0
# ==========================================
# Episode:  905
# Reward:  131.0
# Mean Reward 110.90507726269315
# Max reward so far:  1073.0
# ==========================================
# Episode:  906
# Reward:  154.0
# Mean Reward 110.95259095920618
# Max reward so far:  1073.0
# ==========================================
# Episode:  907
# Reward:  140.0
# Mean Reward 110.98458149779735
# Max reward so far:  1073.0
# ==========================================
# Episode:  908
# Reward:  158.0
# Mean Reward 111.03630363036304
# Max reward so far:  1073.0
# ==========================================
# Episode:  909
# Reward:  146.0
# Mean Reward 111.07472527472528
# Max reward so far:  1073.0
# ==========================================
# Episode:  910
# Reward:  137.0
# Mean Reward 111.10318331503842
# Max reward so far:  1073.0
# ==========================================
# Episode:  911
# Reward:  140.0
# Mean Reward 111.13486842105263
# Max reward so far:  1073.0
# ==========================================
# Episode:  912
# Reward:  146.0
# Mean Reward 111.17305585980284
# Max reward so far:  1073.0
# ==========================================
# Episode:  913
# Reward:  142.0
# Mean Reward 111.20678336980306
# Max reward so far:  1073.0
# ==========================================
# Episode:  914
# Reward:  154.0
# Mean Reward 111.25355191256831
# Max reward so far:  1073.0
# ==========================================
# Episode:  915
# Reward:  142.0
# Mean Reward 111.28711790393012
# Max reward so far:  1073.0
# ==========================================
# Episode:  916
# Reward:  185.0
# Mean Reward 111.36750272628136
# Max reward so far:  1073.0
# ==========================================
# Episode:  917
# Reward:  164.0
# Mean Reward 111.42483660130719
# Max reward so far:  1073.0
# ==========================================
# Episode:  918
# Reward:  253.0
# Mean Reward 111.57889009793253
# Max reward so far:  1073.0
# ==========================================
# Episode:  919
# Reward:  192.0
# Mean Reward 111.66630434782608
# Max reward so far:  1073.0
# ==========================================
# Episode:  920
# Reward:  168.0
# Mean Reward 111.72747014115092
# Max reward so far:  1073.0
# ==========================================
# Episode:  921
# Reward:  155.0
# Mean Reward 111.77440347071584
# Max reward so far:  1073.0
# ==========================================
# Episode:  922
# Reward:  203.0
# Mean Reward 111.87323943661971
# Max reward so far:  1073.0
# ==========================================
# Episode:  923
# Reward:  193.0
# Mean Reward 111.96103896103897
# Max reward so far:  1073.0
# ==========================================
# Episode:  924
# Reward:  127.0
# Mean Reward 111.9772972972973
# Max reward so far:  1073.0
# ==========================================
# Episode:  925
# Reward:  335.0
# Mean Reward 112.2181425485961
# Max reward so far:  1073.0
# ==========================================
# Episode:  926
# Reward:  202.0
# Mean Reward 112.31499460625675
# Max reward so far:  1073.0
# ==========================================
# Episode:  927
# Reward:  139.0
# Mean Reward 112.34375
# Max reward so far:  1073.0
# ==========================================
# Episode:  928
# Reward:  150.0
# Mean Reward 112.38428417653391
# Max reward so far:  1073.0
# ==========================================
# Episode:  929
# Reward:  230.0
# Mean Reward 112.51075268817205
# Max reward so far:  1073.0
# ==========================================
# Episode:  930
# Reward:  166.0
# Mean Reward 112.56820622986037
# Max reward so far:  1073.0
# ==========================================
# Episode:  931
# Reward:  236.0
# Mean Reward 112.70064377682404
# Max reward so far:  1073.0
# ==========================================
# Episode:  932
# Reward:  202.0
# Mean Reward 112.79635584137192
# Max reward so far:  1073.0
# ==========================================
# Episode:  933
# Reward:  192.0
# Mean Reward 112.88115631691649
# Max reward so far:  1073.0
# ==========================================
# Episode:  934
# Reward:  207.0
# Mean Reward 112.98181818181818
# Max reward so far:  1073.0
# ==========================================
# Episode:  935
# Reward:  175.0
# Mean Reward 113.04807692307692
# Max reward so far:  1073.0
# ==========================================
# Episode:  936
# Reward:  188.0
# Mean Reward 113.12806830309498
# Max reward so far:  1073.0
# ==========================================
# Episode:  937
# Reward:  213.0
# Mean Reward 113.23454157782515
# Max reward so far:  1073.0
# ==========================================
# Episode:  938
# Reward:  227.0
# Mean Reward 113.35569755058573
# Max reward so far:  1073.0
# ==========================================
# Episode:  939
# Reward:  209.0
# Mean Reward 113.45744680851064
# Max reward so far:  1073.0
# ==========================================
# Episode:  940
# Reward:  212.0
# Mean Reward 113.56216790648247
# Max reward so far:  1073.0
# ==========================================
# Episode:  941
# Reward:  201.0
# Mean Reward 113.65498938428875
# Max reward so far:  1073.0
# ==========================================
# Episode:  942
# Reward:  166.0
# Mean Reward 113.71049840933192
# Max reward so far:  1073.0
# ==========================================
# Episode:  943
# Reward:  209.0
# Mean Reward 113.8114406779661
# Max reward so far:  1073.0
# ==========================================
# Episode:  944
# Reward:  191.0
# Mean Reward 113.8931216931217
# Max reward so far:  1073.0
# ==========================================
# Episode:  945
# Reward:  214.0
# Mean Reward 113.99894291754757
# Max reward so far:  1073.0
# ==========================================
# Episode:  946
# Reward:  183.0
# Mean Reward 114.07180570221753
# Max reward so far:  1073.0
# ==========================================
# Episode:  947
# Reward:  157.0
# Mean Reward 114.11708860759494
# Max reward so far:  1073.0
# ==========================================
# Episode:  948
# Reward:  219.0
# Mean Reward 114.22760800842993
# Max reward so far:  1073.0
# ==========================================
# Episode:  949
# Reward:  305.0
# Mean Reward 114.42842105263158
# Max reward so far:  1073.0
# ==========================================
# Episode:  950
# Reward:  162.0
# Mean Reward 114.47844374342797
# Max reward so far:  1073.0
# ==========================================
# Episode:  951
# Reward:  256.0
# Mean Reward 114.62710084033614
# Max reward so far:  1073.0
# ==========================================
# Episode:  952
# Reward:  175.0
# Mean Reward 114.69045120671564
# Max reward so far:  1073.0
# ==========================================
# Episode:  953
# Reward:  205.0
# Mean Reward 114.78511530398323
# Max reward so far:  1073.0
# ==========================================
# Episode:  954
# Reward:  226.0
# Mean Reward 114.90157068062827
# Max reward so far:  1073.0
# ==========================================
# Episode:  955
# Reward:  166.0
# Mean Reward 114.9550209205021
# Max reward so far:  1073.0
# ==========================================
# Episode:  956
# Reward:  187.0
# Mean Reward 115.03030303030303
# Max reward so far:  1073.0
# ==========================================
# Episode:  957
# Reward:  237.0
# Mean Reward 115.15762004175366
# Max reward so far:  1073.0
# ==========================================
# Episode:  958
# Reward:  165.0
# Mean Reward 115.20959332638165
# Max reward so far:  1073.0
# ==========================================
# Episode:  959
# Reward:  169.0
# Mean Reward 115.265625
# Max reward so far:  1073.0
# ==========================================
# Episode:  960
# Reward:  101.0
# Mean Reward 115.25078043704474
# Max reward so far:  1073.0
# ==========================================
# Episode:  961
# Reward:  21.0
# Mean Reward 115.15280665280665
# Max reward so far:  1073.0
# ==========================================
# Episode:  962
# Reward:  160.0
# Mean Reward 115.19937694704049
# Max reward so far:  1073.0
# ==========================================
# Episode:  963
# Reward:  166.0
# Mean Reward 115.25207468879668
# Max reward so far:  1073.0
# ==========================================
# Episode:  964
# Reward:  243.0
# Mean Reward 115.38445595854922
# Max reward so far:  1073.0
# ==========================================
# Episode:  965
# Reward:  22.0
# Mean Reward 115.28778467908903
# Max reward so far:  1073.0
# ==========================================
# Episode:  966
# Reward:  258.0
# Mean Reward 115.43536711478801
# Max reward so far:  1073.0
# ==========================================
# Episode:  967
# Reward:  209.0
# Mean Reward 115.53202479338843
# Max reward so far:  1073.0
# ==========================================
# Episode:  968
# Reward:  176.0
# Mean Reward 115.59442724458205
# Max reward so far:  1073.0
# ==========================================
# Episode:  969
# Reward:  199.0
# Mean Reward 115.68041237113403
# Max reward so far:  1073.0
# ==========================================
# Episode:  970
# Reward:  178.0
# Mean Reward 115.74459320288362
# Max reward so far:  1073.0
# ==========================================
# Episode:  971
# Reward:  194.0
# Mean Reward 115.82510288065843
# Max reward so far:  1073.0
# ==========================================
# Episode:  972
# Reward:  289.0
# Mean Reward 116.00308324768757
# Max reward so far:  1073.0
# ==========================================
# Episode:  973
# Reward:  150.0
# Mean Reward 116.03798767967146
# Max reward so far:  1073.0
# ==========================================
# Episode:  974
# Reward:  198.0
# Mean Reward 116.12205128205129
# Max reward so far:  1073.0
# ==========================================
# Episode:  975
# Reward:  226.0
# Mean Reward 116.23463114754098
# Max reward so far:  1073.0
# ==========================================
# Episode:  976
# Reward:  217.0
# Mean Reward 116.33776867963152
# Max reward so far:  1073.0
# ==========================================
# Episode:  977
# Reward:  318.0
# Mean Reward 116.5439672801636
# Max reward so far:  1073.0
# ==========================================
# Episode:  978
# Reward:  255.0
# Mean Reward 116.68539325842697
# Max reward so far:  1073.0
# ==========================================
# Episode:  979
# Reward:  232.0
# Mean Reward 116.8030612244898
# Max reward so far:  1073.0
# ==========================================
# Episode:  980
# Reward:  278.0
# Mean Reward 116.96738022426096
# Max reward so far:  1073.0
# ==========================================
# Episode:  981
# Reward:  299.0
# Mean Reward 117.15274949083503
# Max reward so far:  1073.0
# ==========================================
# Episode:  982
# Reward:  54.0
# Mean Reward 117.08850457782299
# Max reward so far:  1073.0
# ==========================================
# Episode:  983
# Reward:  203.0
# Mean Reward 117.17581300813008
# Max reward so far:  1073.0
# ==========================================
# Episode:  984
# Reward:  187.0
# Mean Reward 117.24670050761421
# Max reward so far:  1073.0
# ==========================================
# Episode:  985
# Reward:  209.0
# Mean Reward 117.33975659229209
# Max reward so far:  1073.0
# ==========================================
# Episode:  986
# Reward:  259.0
# Mean Reward 117.48328267477204
# Max reward so far:  1073.0
# ==========================================
# Episode:  987
# Reward:  366.0
# Mean Reward 117.73481781376518
# Max reward so far:  1073.0
# ==========================================
# Episode:  988
# Reward:  376.0
# Mean Reward 117.99595551061678
# Max reward so far:  1073.0
# ==========================================
# Episode:  989
# Reward:  216.0
# Mean Reward 118.09494949494949
# Max reward so far:  1073.0
# ==========================================
# Episode:  990
# Reward:  265.0
# Mean Reward 118.24318869828456
# Max reward so far:  1073.0
# ==========================================
# Episode:  991
# Reward:  340.0
# Mean Reward 118.46673387096774
# Max reward so far:  1073.0
# ==========================================
# Episode:  992
# Reward:  220.0
# Mean Reward 118.56898288016113
# Max reward so far:  1073.0
# ==========================================
# Episode:  993
# Reward:  255.0
# Mean Reward 118.70623742454728
# Max reward so far:  1073.0
# ==========================================
# Episode:  994
# Reward:  272.0
# Mean Reward 118.86030150753768
# Max reward so far:  1073.0
# ==========================================
# Episode:  995
# Reward:  263.0
# Mean Reward 119.00502008032129
# Max reward so far:  1073.0
# ==========================================
# Episode:  996
# Reward:  27.0
# Mean Reward 118.91273821464394
# Max reward so far:  1073.0
# ==========================================
# Episode:  997
# Reward:  334.0
# Mean Reward 119.12825651302605
# Max reward so far:  1073.0
# ==========================================
# Episode:  998
# Reward:  221.0
# Mean Reward 119.23023023023023
# Max reward so far:  1073.0
# ==========================================
# Episode:  999
# Reward:  201.0
# Mean Reward 119.312
# Max reward so far:  1073.0

# %% [markdown]
# ## Step 9: Watch our Agent try to balance a rod 👀
# Now that we trained our agent, we can test it

# %%
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay



def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
playing_env = wrap_env(gym.make('CartPole-v0'))

# %%
saver = tf.train.Saver()
with tf.Session() as sess:    
    # Load the model
    saver.restore(sess, "./models/model.ckpt")

    state = playing_env.reset()
    step = 0
    done = False

    while True:
        

        # Choose action a, remember WE'RE NOT IN A DETERMINISTIC ENVIRONMENT, WE'RE OUTPUT PROBABILITIES.
        action_probability_distribution = sess.run(action_distribution, feed_dict={input_: state.reshape([1,4])})
        #print(action_probability_distribution)
        action = np.random.choice(range(action_probability_distribution.shape[1]), p=action_probability_distribution.ravel())  # select action w.r.t the actions prob


        new_state, reward, done, info = playing_env.step(action)

        total_rewards += reward

        if done:
            print ("Score", total_rewards)
            break
        state = new_state

    playing_env.close()
# Out:
# INFO:tensorflow:Restoring parameters from ./models/model.ckpt
# Score 119488.0

# %%
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
